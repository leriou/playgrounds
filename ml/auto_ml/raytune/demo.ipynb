# %%
# Import the RL algorithm (Trainer) we would like to use.
from ray.rllib.agents.ppo import PPOTrainer

# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 2,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "torch",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    },
}

# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)

# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())

# Evaluate the trained Trainer (and render each timestep to the shell's
# output).
trainer.evaluate()
# Out:
# /opt/homebrew/lib/python3.9/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# 2022-04-26 00:43:19,275	WARNING trainer.py:2503 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-04-26 00:43:21,087	INFO services.py:1456 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=3684) /opt/homebrew/lib/python3.9/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
# (pid=3684)   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# (pid=3685) /opt/homebrew/lib/python3.9/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
# (pid=3685)   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# (RolloutWorker pid=3684) 2022-04-26 00:43:23,858	WARNING rollout_worker.py:498 -- We've added a module for checking environments that are used in experiments. It will cause your environment to fail if your environment is not set upcorrectly. You can disable check env by setting `disable_env_checking` to True in your experiment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env(env).
# (RolloutWorker pid=3685) 2022-04-26 00:43:23,858	WARNING rollout_worker.py:498 -- We've added a module for checking environments that are used in experiments. It will cause your environment to fail if your environment is not set upcorrectly. You can disable check env by setting `disable_env_checking` to True in your experiment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env(env).
# 2022-04-26 00:43:23,905	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# 2022-04-26 00:43:23,905	WARNING trainer.py:2503 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
# 2022-04-26 00:43:23,932	WARNING util.py:60 -- Install gputil for GPU system monitoring.
# (pid=3686) /opt/homebrew/lib/python3.9/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
# (pid=3686)   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# (RolloutWorker pid=3686) 2022-04-26 00:43:25,203	WARNING rollout_worker.py:498 -- We've added a module for checking environments that are used in experiments. It will cause your environment to fail if your environment is not set upcorrectly. You can disable check env by setting `disable_env_checking` to True in your experiment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env(env).
# {'episode_reward_max': -459.0, 'episode_reward_min': -974.0, 'episode_reward_mean': -810.1, 'episode_len_mean': 196.0, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-929.0, -830.0, -459.0, -641.0, -821.0, -848.0, -893.0, -866.0, -884.0, -785.0, -974.0, -749.0, -803.0, -902.0, -839.0, -821.0, -821.0, -767.0, -794.0, -776.0], 'episode_lengths': [200, 200, 120, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.03383679130207236, 'mean_inference_ms': 0.2434526545473601, 'mean_action_processing_ms': 0.014960736051194374, 'mean_env_wait_ms': 0.017763316065355993, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 4000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 4000, 'timers': {'sample_time_ms': 699.18, 'sample_throughput': 5720.988, 'load_time_ms': 0.175, 'load_throughput': 22857242.507, 'learn_time_ms': 1497.634, 'learn_throughput': 2670.88, 'update_time_ms': 0.719}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.947955989837647, 'policy_loss': 0.007450148607453993, 'vf_loss': 9.940397699417607, 'vf_explained_var': 3.086879689206359e-06, 'kl': 0.0005406865196580072, 'entropy': 1.7912210368341015, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_steps_sampled': 4000, 'num_agent_steps_sampled': 4000, 'num_steps_trained': 4000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'experiment_id': 'd9f715b734384c98a2b00ca47e72f492', 'date': '2022-04-26_00-43-26', 'timestamp': 1650905006, 'time_this_iter_s': 2.170867919921875, 'time_total_s': 2.170867919921875, 'pid': 3645, 'hostname': 'lerioudeair', 'node_ip': '127.0.0.1', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sys_usage': True, 'fake_sampler': False, 'framework': 'torch', 'eager_tracing': False, 'eager_max_retraces': 2 ...
# {'episode_reward_max': -246.0, 'episode_reward_min': -974.0, 'episode_reward_mean': -757.75, 'episode_len_mean': 195.175, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-929.0, -830.0, -459.0, -641.0, -821.0, -848.0, -893.0, -866.0, -884.0, -785.0, -974.0, -749.0, -803.0, -902.0, -839.0, -821.0, -821.0, -767.0, -794.0, -776.0, -830.0, -246.0, -686.0, -695.0, -830.0, -830.0, -641.0, -686.0, -731.0, -695.0, -695.0, -731.0, -686.0, -713.0, -758.0, -740.0, -722.0, -623.0, -758.0, -812.0], 'episode_lengths': [200, 200, 120, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.03317786044315572, 'mean_inference_ms': 0.23961734263896411, 'mean_action_processing_ms': 0.014734272661430108, 'mean_env_wait_ms': 0.017458812597910895, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 8000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'sample_time_ms': 1408.146, 'sample_throughput': 2840.614, 'load_time_ms': 0.167, 'load_throughput': 23950344.04, 'learn_time_ms': 1451.947, 'learn_throughput': 2754.921, 'update_time_ms': 0.7}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.883160987977059, 'policy_loss': 0.0002636632731845302, 'vf_loss': 9.882019951522992, 'vf_explained_var': -0.00013346518239667338, 'kl': 0.008773969835917396, 'entropy': 1.7722171691156203, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_steps_sampled': 8000, 'num_agent_steps_sampled': 8000, 'num_steps_trained': 8000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 8000}, 'done': False, 'episodes_total': 40, 'training_iteration': 2, 'trial_id': 'default', 'experiment_id': 'd9f715b734384c98a2b00ca47e72f492', 'date': '2022-04-26_00-43-28', 'timestamp': 1650905008, 'time_this_iter_s': 2.018157958984375, 'time_total_s': 4.18902587890625, 'pid': 3645, 'hostname': 'lerioudeair', 'node_ip': '127.0.0.1', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': 'Taxi-v3', 'observation_space': None, 'action_space': None, 'env_config': {}, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'prepr ...
# {'episode_reward_max': -246.0, 'episode_reward_min': -974.0, 'episode_reward_mean': -700.327868852459, 'episode_len_mean': 196.47540983606558, 'episode_media': {}, 'episodes_this_iter': 21, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-929.0, -830.0, -459.0, -641.0, -821.0, -848.0, -893.0, -866.0, -884.0, -785.0, -974.0, -749.0, -803.0, -902.0, -839.0, -821.0, -821.0, -767.0, -794.0, -776.0, -830.0, -246.0, -686.0, -695.0, -830.0, -830.0, -641.0, -686.0, -731.0, -695.0, -695.0, -731.0, -686.0, -713.0, -758.0, -740.0, -722.0, -623.0, -758.0, -812.0, -677.0, -632.0, -506.0, -569.0, -542.0, -578.0, -668.0, -418.0, -605.0, -578.0, -524.0, -659.0, -605.0, -596.0, -587.0, -614.0, -641.0, -605.0, -668.0, -497.0, -641.0], 'episode_lengths': [200, 200, 120, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 178, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.03279564897574291, 'mean_inference_ms': 0.23745093096955802, 'mean_action_processing_ms': 0.01458917408436932, 'mean_env_wait_ms': 0.017276435006754767, 'mean_env_render_ms': 0.0}, 'off_policy_estimator': {}, 'num_healthy_workers': 2, 'timesteps_total': 12000, 'timesteps_this_iter': 4000, 'agent_timesteps_total': 12000, 'timers': {'sample_time_ms': 1614.148, 'sample_throughput': 2478.088, 'load_time_ms': 0.147, 'load_throughput': 27206296.216, 'learn_time_ms': 1434.044, 'learn_throughput': 2789.315, 'update_time_ms': 0.663}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.839171659818259, 'policy_loss': 0.0010404300815876452, 'vf_loss': 9.837689100286012, 'vf_explained_var': -0.0004366114575375793, 'kl': 0.004421234061719017, 'entropy': 1.742826250804368, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0}}, 'num_steps_sampled': 12000, 'num_agent_steps_sampled': 12000, 'num_steps_trained': 12000, 'num_steps_trained_this_iter': 4000, 'num_agent_steps_trained': 12000}, 'done': False, 'episodes_total': 61, 'training_iteration': 3, 'trial_id': 'default', 'experiment_id': 'd9f715b734384c98a2b00ca47e72f492', 'date': '2022-04-26_00-43-30', 'timestamp': 1650905010, 'time_this_iter_s': 2.0105819702148438, 'time_total_s': 6.199607849121094, 'pid': 3645, 'hostname': 'lerioudeair', 'node_ip': '127.0.0.1', 'config': {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, '_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [64, 64], 'fcnet_activation': 'relu', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_ ...
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# ...
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (East)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Pickup)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (South)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (Dropoff)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (West)
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686) |R: | : :G|
# (RolloutWorker pid=3686) | : | : : |
# (RolloutWorker pid=3686) | : : : : |
# (RolloutWorker pid=3686) | | : | : |
# (RolloutWorker pid=3686) |Y| : |B: |
# (RolloutWorker pid=3686) +---------+
# (RolloutWorker pid=3686)   (North)
