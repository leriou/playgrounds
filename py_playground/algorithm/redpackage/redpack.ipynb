# %%
import random


def gen_red_package(amount, num, min_size, max_size):
    amount *= 100
    lines = [0, amount]
    # 生成num-1个符合要求的随机的点
    for i in range(0, num - 1):
        loop = True
        while loop:
            r = random.Random().randint(0, amount)
            loop = not is_valid(lines, r, min_size * 100, max_size * 100)
    # 生成红包        
    paks = []
    for j in range(0, len(lines) - 1):
        paks.append((lines[j+1] - lines[j])/100)
    return paks

def is_valid(arr, value, min_size, max_size) -> bool:
    if arr.__contains__(value):
        return False
    arr.append(value)
    arr.sort()
    curr = arr.index(value)
    l = arr[max(0, curr - 1)]
    r = arr[min(curr + 1, len(arr) - 1)]
    dl = value - l
    dr = r - value
    if dl >= min_size and dr >= min_size and dl <= max_size and dr <= max_size:
        return True
    arr.remove(value)
    return False

print(gen_red_package(2000, 20, 1, 1900))
# Out:
# [237.25, 119.55, 39.93, 36.3, 164.37, 105.08, 227.57, 27.42, 13.56, 170.31, 61.64, 92.98, 62.66, 177.19, 54.4, 223.25, 39.26, 19.31, 120.39, 7.58]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

amount = 2000
nums = 20
min_amount = 1
max_amount = 1900

step = 1
stat = {}
pos = {}
for i in range(0,2000):
    packages = gen_red_package(amount, nums, min_amount, max_amount)
    idx = 1
    for n in packages:
        t = n // step
        if stat.__contains__(t):
            stat[t] += 1
        else:
            stat[t] = 1

        if pos.__contains__(idx):
            pos[idx] += n
        else:
            pos[idx] = n
        idx += 1 
        

fig, ax = plt.subplots()  
ax.bar(np.array([i*step for i in stat.keys()]),np.array([i for i in stat.values()]));

fig2, bx = plt.subplots()  
bx.bar(np.array([i for i in pos.keys()]),np.array([i for i in pos.values()]));

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

fig, ax = plt.subplots()  # Create a figure containing a single axes.
# ax.plot(np.arange(5,20,2), np.arange(0,100,10)[:8])  # Plot some data on the axes.
ax.bar(np.arange(5,10),np.arange(20,50,6));
